# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishnupriya1505/Learn/blob/Learn/Student%20Performance%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'studyhours':[2,3,4,5,6],
    'marks':[50,60,70,80,90],
    'attendance':[30,59,60,83,90]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    studyhours  marks  attendance
# 0           2     50          30
# 1           3     60          59
# 2           4     70          60
# 3           5     80          83
# 4           6     90          90

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['studyhours', 'marks', 'attendance'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   studyhours  5 non-null      int64
#  1   marks       5 non-null      int64
#  2   attendance  5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df.describe()
# Out:
#        studyhours      marks  attendance
# count    5.000000   5.000000    5.000000
# mean     4.000000  70.000000   64.400000
# std      1.581139  15.811388   23.628373
# min      2.000000  50.000000   30.000000
# 25%      3.000000  60.000000   59.000000
# 50%      4.000000  70.000000   60.000000
# 75%      5.000000  80.000000   83.000000
# max      6.000000  90.000000   90.000000

# %%
df.isnull()
# Out:
#    studyhours  marks  attendance
# 0       False  False       False
# 1       False  False       False
# 2       False  False       False
# 3       False  False       False
# 4       False  False       False

# %%
df.isnull().sum()
# Out:
# studyhours    0
# marks         0
# attendance    0
# dtype: int64

# %%
plt.scatter(df['studyhours'], df['marks'])
plt.xlabel('studyhours')
plt.ylabel('marks')
plt.title('studyhours vs marks')
plt.show()

# %%
X=df[['studyhours', 'attendance', 'marks']]

# %%
Y=df['marks']
